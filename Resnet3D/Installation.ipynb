# %%
pip install --upgrade pip
# Out:
# Collecting pip
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/a4/6d/6463d49a933f547439d6b5b98b46af8742cc03ae83543e4d7688c2420f8b/pip-21.3.1-py3-none-any.whl (1.7MB)
#     100% |████████████████████████████████| 1.7MB 860kB/s eta 0:00:01
# Installing collected packages: pip
# Successfully installed pip-21.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 7.7 MB/s
# Installing collected packages: numpy
# Successfully installed numpy-1.19.5

# %%
import sys
# !{sys.executable} -m pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.6.2-cp36-cp36m-manylinux2010_x86_64.whl (458.3 MB)
#      |██████████████████████          | 316.3 MB 127.6 MB/s eta 0:00:02MB/s eta 0:00:02
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████▊   | 410.7 MB 107.9 MB/s eta 0:00:01
#      |█████████████████████████████   | 416.4 MB 107.9 MB/s eta 0:00:01
#      |█████████████████████████████▌  | 421.8 MB 107.9 MB/s eta 0:00:01
#      |█████████████████████████████▉  | 426.8 MB 100.1 MB/s eta 0:00:01
#      |██████████████████████████████▏ | 431.7 MB 100.1 MB/s eta 0:00:01
#      |██████████████████████████████▌ | 436.6 MB 100.1 MB/s eta 0:00:01
#      |██████████████████████████████▉ | 441.8 MB 100.1 MB/s eta 0:00:01
#      |███████████████████████████████▎| 447.6 MB 100.1 MB/s eta 0:00:01
#      |███████████████████████████████▋| 452.7 MB 100.1 MB/s eta 0:00:01
#      |████████████████████████████████| 458.3 MB 100.1 MB/s eta 0:00:01
#      |████████████████████████████████| 458.3 MB 29 kB/s
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.7 MB/s
# Collecting wheel~=0.35
#   Downloading wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 78.4 MB/s
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy~=1.19.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 81.2 MB/s
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 98.3 MB/s
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 103.4 MB/s
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow) (3.19.1)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting grpcio<2.0,>=1.37.0
#   Downloading grpcio-1.41.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 65.3 MB/s
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 10.7 MB/s
# Requirement already satisfied: absl-py~=0.10 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow) (0.15.0)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 7.0 MB/s
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (58.5.2)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 14.3 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 83.7 MB/s
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 105.4 MB/s
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 87.1 MB/s
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 41.9 MB/s
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.2.1)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/.local/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (4.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.22)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2018.1.18)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.6)
# Requirement already satisfied: dataclasses in /home/ubuntu/.local/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow) (0.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 68.0 MB/s
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/.local/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow) (3.6.0)
# Building wheels for collected packages: clang, termcolor, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=32130 sha256=b7627d75a6e234eda04bf5408790b85433df59b5919142b8160f518ddde1477c
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/22/4c/94/0583f60c9c5b6024ed64f290cb2d43b06bb4f75577dc3c93a7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=5714 sha256=662595e72603c91256d45141817abd7955112439e1d3cf5469e970d82b906caf
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69395 sha256=960a5b8521dbf5667aa2e675d2bb25690128a7c119f6177fb8b96540b72a049a
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built clang termcolor wrapt
# Installing collected packages: charset-normalizer, typing-extensions, six, rsa, requests, oauthlib, cachetools, requests-oauthlib, google-auth, wheel, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, markdown, grpcio, google-auth-oauthlib, cached-property, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
# Successfully installed astunparse-1.6.3 cached-property-1.5.2 cachetools-4.2.4 charset-normalizer-2.0.7 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.41.1 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.4 oauthlib-3.1.1 opt-einsum-3.3.0 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 werkzeug-2.0.2 wheel-0.37.0 wrapt-1.12.1

# %%
import sys
# !{sys.executable} -m pip install wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wheel in /home/ubuntu/.local/lib/python3.6/site-packages (0.37.0)

# %%
import sys
# !{sys.executable} -m pip install joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 7.9 MB/s
# Installing collected packages: joblib
# Successfully installed joblib-1.1.0

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 6.2 MB/s
# Collecting pytz>=2017.2
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/ubuntu/.local/lib/python3.6/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/.local/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.1.5 pytz-2021.3

# %%
import sys
# !{sys.executable} -m pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 6.1 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /home/ubuntu/.local/lib/python3.6/site-packages (from scipy) (1.19.5)
# Installing collected packages: scipy
# Successfully installed scipy-1.5.4

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
#      |████████████████████████████████| 22.2 MB 6.3 MB/s
# Requirement already satisfied: joblib>=0.11 in /home/ubuntu/.local/lib/python3.6/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from scikit-learn) (1.5.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-0.24.2 threadpoolctl-3.0.0

# %%
print (sys.executable)
# Out:
# /usr/bin/python3

# %%
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install "tensorflow-probability>=0.8.0rc0" --pre
# !pip3 install "dm-sonnet>=2.0.0b0" --pre
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.6.2-cp36-cp36m-manylinux2010_x86_64.whl (458.3 MB)
#      |█████████████████████████▋      | 366.1 MB 128.4 MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |███████████████████████████████▍| 449.9 MB 128.4 MB/s eta 0:00:01
#      |███████████████████████████████▉| 455.7 MB 128.4 MB/s eta 0:00:01
#      |████████████████████████████████| 458.3 MB 128.4 MB/s eta 0:00:01
#      |████████████████████████████████| 458.3 MB 17 kB/s
# Requirement already satisfied: numpy~=1.19.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.19.5)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (0.37.0)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (2.6.0)
# Requirement already satisfied: clang~=5.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.41.1)
# Requirement already satisfied: astunparse~=1.6.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (3.19.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (0.15.0)
# Requirement already satisfied: gast==0.4.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: cached-property in /home/ubuntu/.local/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (58.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ubuntu/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (0.2.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/.local/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (4.8.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (2018.1.18)
# Requirement already satisfied: dataclasses in /home/ubuntu/.local/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (0.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/.local/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow-gpu) (3.6.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.6.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-probability>=0.8.0rc0
#   Downloading tensorflow_probability-0.15.0-py2.py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 7.8 MB/s
# Collecting cloudpickle>=1.3
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.10.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-probability>=0.8.0rc0) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-probability>=0.8.0rc0) (1.19.5)
# Collecting dm-tree
#   Downloading dm_tree-0.1.6-cp36-cp36m-manylinux_2_24_x86_64.whl (93 kB)
#      |████████████████████████████████| 93 kB 4.6 MB/s
# Requirement already satisfied: absl-py in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-probability>=0.8.0rc0) (0.15.0)
# Requirement already satisfied: gast>=0.3.2 in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-probability>=0.8.0rc0) (0.4.0)
# Requirement already satisfied: decorator in /home/ubuntu/.local/lib/python3.6/site-packages (from tensorflow-probability>=0.8.0rc0) (5.1.0)
# Installing collected packages: dm-tree, cloudpickle, tensorflow-probability
# Successfully installed cloudpickle-2.0.0 dm-tree-0.1.6 tensorflow-probability-0.15.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dm-sonnet>=2.0.0b0
#   Downloading dm_sonnet-2.0.0-py3-none-any.whl (254 kB)
#      |████████████████████████████████| 254 kB 7.2 MB/s
# Requirement already satisfied: dm-tree>=0.1.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from dm-sonnet>=2.0.0b0) (0.1.6)
# Requirement already satisfied: six>=1.12.0 in /home/ubuntu/.local/lib/python3.6/site-packages (from dm-sonnet>=2.0.0b0) (1.15.0)
# Requirement already satisfied: numpy>=1.16.3 in /home/ubuntu/.local/lib/python3.6/site-packages (from dm-sonnet>=2.0.0b0) (1.19.5)
# Requirement already satisfied: absl-py>=0.7.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from dm-sonnet>=2.0.0b0) (0.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /home/ubuntu/.local/lib/python3.6/site-packages (from dm-sonnet>=2.0.0b0) (1.12.1)
# Collecting tabulate>=0.7.5
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Installing collected packages: tabulate, dm-sonnet
# Successfully installed dm-sonnet-2.0.0 tabulate-0.8.9
